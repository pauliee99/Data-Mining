# %%
# importing pandas package  
import pandas as pd  
    
# making data frame from csv file  
df = pd.read_csv("https://raw.githubusercontent.com/RohitLearner/House-Prices-Visualization-Prediction/master/input/train.csv")
df.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
df['Alley'].isnull().sum()
# Out:
# 1369

# %%
percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percent_missing': percent_missing})

# %%
missing_value_df
# Out:
#                  column_name  percent_missing
# Id                        Id         0.000000
# MSSubClass        MSSubClass         0.000000
# MSZoning            MSZoning         0.000000
# LotFrontage      LotFrontage        17.739726
# LotArea              LotArea         0.000000
# ...                      ...              ...
# MoSold                MoSold         0.000000
# YrSold                YrSold         0.000000
# SaleType            SaleType         0.000000
# SaleCondition  SaleCondition         0.000000
# SalePrice          SalePrice         0.000000
#
# [81 rows x 2 columns]

# %%
len(df)
# Out:
# 1460

# %%
missing_value_df[missing_value_df['percent_missing']>0]
# Out:
#                column_name  percent_missing
# LotFrontage    LotFrontage        17.739726
# Alley                Alley        93.767123
# MasVnrType      MasVnrType         0.547945
# MasVnrArea      MasVnrArea         0.547945
# BsmtQual          BsmtQual         2.534247
# BsmtCond          BsmtCond         2.534247
# BsmtExposure  BsmtExposure         2.602740
# BsmtFinType1  BsmtFinType1         2.534247
# BsmtFinType2  BsmtFinType2         2.602740
# Electrical      Electrical         0.068493
# FireplaceQu    FireplaceQu        47.260274
# GarageType      GarageType         5.547945
# GarageYrBlt    GarageYrBlt         5.547945
# GarageFinish  GarageFinish         5.547945
# GarageQual      GarageQual         5.547945
# GarageCond      GarageCond         5.547945
# PoolQC              PoolQC        99.520548
# Fence                Fence        80.753425
# MiscFeature    MiscFeature        96.301370

# %%
df['Electrical'].unique()
# Out:
# array(['SBrkr', 'FuseF', 'FuseA', 'FuseP', 'Mix', nan], dtype=object)

# %%
df['Electrical'] = df['Electrical'].fillna('Unknown')

# %%
df
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0        1          60       RL  ...        WD         Normal    208500
# 1        2          20       RL  ...        WD         Normal    181500
# 2        3          60       RL  ...        WD         Normal    223500
# 3        4          70       RL  ...        WD        Abnorml    140000
# 4        5          60       RL  ...        WD         Normal    250000
# ...    ...         ...      ...  ...       ...            ...       ...
# 1455  1456          60       RL  ...        WD         Normal    175000
# 1456  1457          20       RL  ...        WD         Normal    210000
# 1457  1458          70       RL  ...        WD         Normal    266500
# 1458  1459          20       RL  ...        WD         Normal    142125
# 1459  1460          20       RL  ...        WD         Normal    147500
#
# [1460 rows x 81 columns]

# %%
df.groupby('GarageYrBlt').count()
# Out:
#              Id  MSSubClass  MSZoning  ...  SaleType  SaleCondition  SalePrice
# GarageYrBlt                            ...
# 1900.0        1           1         1  ...         1              1          1
# 1906.0        1           1         1  ...         1              1          1
# 1908.0        1           1         1  ...         1              1          1
# 1910.0        3           3         3  ...         3              3          3
# 1914.0        2           2         2  ...         2              2          2
# ...          ..         ...       ...  ...       ...            ...        ...
# 2006.0       59          59        59  ...        59             59         59
# 2007.0       49          49        49  ...        49             49         49
# 2008.0       29          29        29  ...        29             29         29
# 2009.0       21          21        21  ...        21             21         21
# ...

# %%
import seaborn as sns
#sns.countplot(x='GarageYrBlt',data=df)
sns.countplot(x='Street',data=df)

# %%
mean_value=int(df['GarageYrBlt'].mean())
mean_value
# Out:
# 1978

# %%
df['GarageYrBlt'] = df['GarageYrBlt'].fillna(mean_value)

# %%
sns.countplot(x='MasVnrArea',data=df)

# %%
df['MasVnrArea'].isnull().sum()
# Out:
# 0

# %%
df['MasVnrArea']=df['MasVnrArea'].interpolate(method ='linear', limit_direction ='forward')
